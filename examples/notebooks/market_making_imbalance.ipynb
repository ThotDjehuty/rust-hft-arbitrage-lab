# %% [markdown]
# # Market Making (Imbalance)\n

# %%
import requests, pandas as pd, matplotlib.pyplot as plt
BASE='http://mock_apis:8000'
ob = requests.get(f"{BASE}/api/binance/orderbook/BTCUSDT?depth=40").json()
bids = pd.DataFrame(ob['bids'], columns=['price','size']).astype(float).sort_values('price', ascending=False)
asks = pd.DataFrame(ob['asks'], columns=['price','size']).astype(float).sort_values('price', ascending=True)
I = (bids['size'][:10].sum() - asks['size'][:10].sum())/(bids['size'][:10].sum() + asks['size'][:10].sum())
mid = (bids.iloc[0,0] + asks.iloc[0,0])/2
print('imbalance', I, 'mid', mid)
